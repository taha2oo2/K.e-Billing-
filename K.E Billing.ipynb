# %%
def electricity(monthly_units):
    if(monthly_units<=100):
        return monthly_units*9.43
    elif(monthly_units>100 and monthly_units<=200):
        return monthly_units*10.49
    
    elif(monthly_units>200 and monthly_units<=300):
        return monthly_units*12.55
    
    elif(monthly_units>300 and monthly_units<=400):
        return monthly_units*17.38
    
    elif(monthly_units>400 and monthly_units<=500):
        return monthly_units*18.84
    
    elif(monthly_units>500 and monthly_units<=600):
         return monthly_units*19.76
    
    elif(monthly_units>600 and monthly_units<=700):
        return monthly_units*20.40
    
    else:
        return monthly_units*23.87
    
def uniform(monthly_units):
    if(monthly_units<=100):
        return monthly_units*13.41
    elif(monthly_units>100 and monthly_units<=200):
        return monthly_units*14.36
    
    elif(monthly_units>200 and monthly_units<=300):
        return monthly_units*16.97
    
    elif(monthly_units>300 and monthly_units<=400):
        return monthly_units*21.93
    
    elif(monthly_units>400 and monthly_units<=500):
        return monthly_units*23.39
    
    elif(monthly_units>500 and monthly_units<=600):
         return monthly_units*24.31
    
    elif(monthly_units>600 and monthly_units<=700):
        return monthly_units*24.95
    
    else:
        return monthly_units*29.37
    
def fuel_charges(monthly_units):
    if(monthly_units<=100):
        return monthly_units*13.41
    elif(monthly_units>100 and monthly_units<=200):
        return monthly_units*14.36
    
    elif(monthly_units>200 and monthly_units<=300):
        return monthly_units*16.97
    
    elif(monthly_units>300 and monthly_units<=400):
        return monthly_units*21.93
    
    elif(monthly_units>400 and monthly_units<=500):
        return monthly_units*23.39
    
    elif(monthly_units>500 and monthly_units<=600):
         return monthly_units*24.31
    
    elif(monthly_units>600 and monthly_units<=700):
        return monthly_units*24.95
    
    else:
        return monthly_units*29.37
    
def sales_tax(monthly_units):
    if(monthly_units<=100):
        return monthly_units*13.41
    elif(monthly_units>100 and monthly_units<=200):
        return monthly_units*14.36
    
    elif(monthly_units>200 and monthly_units<=300):
        return monthly_units*16.97
    
    elif(monthly_units>300 and monthly_units<=400):
        return monthly_units*21.93
    
    elif(monthly_units>400 and monthly_units<=500):
        return monthly_units*23.39
    
    elif(monthly_units>500 and monthly_units<=600):
         return monthly_units*24.31
    
    elif(monthly_units>600 and monthly_units<=700):
        return monthly_units*24.95
    
    else:
        return monthly_units*29.37
    
def advance_tax(monthly_units):
    if(monthly_units<=100):
        return monthly_units*13.41
    elif(monthly_units>100 and monthly_units<=200):
        return monthly_units*14.36
    
    elif(monthly_units>200 and monthly_units<=300):
        return monthly_units*16.97
    
    elif(monthly_units>300 and monthly_units<=400):
        return monthly_units*21.93
    
    elif(monthly_units>400 and monthly_units<=500):
        return monthly_units*23.39
    
    elif(monthly_units>500 and monthly_units<=600):
         return monthly_units*24.31
    
    elif(monthly_units>600 and monthly_units<=700):
        return monthly_units*24.95
    
    else:
        return monthly_units*29.37
    
def tv_fee(monthly_units):
    if(monthly_units<=100):
        return monthly_units*13.41
    elif(monthly_units>100 and monthly_units<=200):
        return monthly_units*14.36
    
    elif(monthly_units>200 and monthly_units<=300):
        return monthly_units*16.97
    
    elif(monthly_units>300 and monthly_units<=400):
        return monthly_units*21.93
    
    elif(monthly_units>400 and monthly_units<=500):
        return monthly_units*23.39
    
    elif(monthly_units>500 and monthly_units<=600):
         return monthly_units*24.31
    
    elif(monthly_units>600 and monthly_units<=700):
        return monthly_units*24.95
    
    else:
        return monthly_units*29.37
    
def bill_main(monthly_units):
    print("Total Per unit charges for", monthly_units,"=",electricity(monthly_units))
    print("Uniform Charges for",monthly_units,"=",uniform(monthly_units))
    print("Fuel Charges for",monthly_units,"=",fuel_charges(monthly_units))
    print("Sales Tax for",monthly_units,"=",sales_tax(monthly_units))
    print("Advance Tax for",monthly_units,"=",advance_tax(monthly_units))
    print("Tv fee for",monthly_units,"=",tv_fee(monthly_units))
    print("Total:",electricity(monthly_units)+uniform(monthly_units)+fuel_charges(monthly_units)+sales_tax(monthly_units)+advance_tax(monthly_units)+tv_fee(monthly_units))
    
a=int(input("Enter your Units:"))
bill_main(a)
# Out:
# Enter your Units:456
# Total Per unit charges for 456 = 8591.039999999999
# Uniform Charges for 456 = 10665.84
# Fuel Charges for 456 = 10665.84
# Sales Tax for 456 = 10665.84
# Advance Tax for 456 = 10665.84
# Tv fee for 456 = 10665.84
# Total: 61920.23999999999
